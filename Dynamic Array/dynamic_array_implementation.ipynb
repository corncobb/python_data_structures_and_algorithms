# %%
# Imports
import ctypes

# Class
class DynamicArray(object):
    
    def __init__(self):
        
        self.n = 0
        self.capacity = 1
        self.A = self.make_array(self.capacity)
        
    def __len__(self):
        return self.n
    
    def __getitem__(self, k):
        
        if not 0 <= k < self.n:
            return IndexError('K is out of bounds!')
        
        return self.A[k]
    
    def append(self, ele):
        
        if self.n == self.capacity:
            self._resize(2*self.capacity) # 2x if capacity is not enough
            
        self.A[self.n] = ele
        self.n += 1
        
    def _resize(self, new_cap):
        
        B = self.make_array(new_cap) 
        
        for k in range(self.n):
            B[k] = self.A[k]
            
        self.A = B
        self.capacity = new_cap
        
    def make_array(self, new_cap):
        
        # Returns a new array with new_cap capacity
        return (new_cap * ctypes.py_object)()

# %%
import sys
from ctypes import sizeof

n = 50

data = DynamicArray()

for i in range(n):
    a = len(data)
    
    b = sizeof(data.A)
    
    print('Length: {0:3d}; Size in bytes: {1:4}'.format(a,b))
    
    data.append(n)
# Out:
# Length:   0; Size in bytes:    4
# Length:   1; Size in bytes:    4
# Length:   2; Size in bytes:    8
# Length:   3; Size in bytes:   16
# Length:   4; Size in bytes:   16
# Length:   5; Size in bytes:   32
# Length:   6; Size in bytes:   32
# Length:   7; Size in bytes:   32
# Length:   8; Size in bytes:   32
# Length:   9; Size in bytes:   64
# Length:  10; Size in bytes:   64
# Length:  11; Size in bytes:   64
# Length:  12; Size in bytes:   64
# Length:  13; Size in bytes:   64
# Length:  14; Size in bytes:   64
# Length:  15; Size in bytes:   64
# Length:  16; Size in bytes:   64
# Length:  17; Size in bytes:  128
# Length:  18; Size in bytes:  128
# Length:  19; Size in bytes:  128
# Length:  20; Size in bytes:  128
# Length:  21; Size in bytes:  128
# Length:  22; Size in bytes:  128
# Length:  23; Size in bytes:  128
# Length:  24; Size in bytes:  128
# Length:  25; Size in bytes:  128
# Length:  26; Size in bytes:  128
# Length:  27; Size in bytes:  128
# Length:  28; Size in bytes:  128
# Length:  29; Size in bytes:  128
# Length:  30; Size in bytes:  128
# Length:  31; Size in bytes:  128
# Length:  32; Size in bytes:  128
# Length:  33; Size in bytes:  256
# Length:  34; Size in bytes:  256
# Length:  35; Size in bytes:  256
# Length:  36; Size in bytes:  256
# Length:  37; Size in bytes:  256
# Length:  38; Size in bytes:  256
# Length:  39; Size in bytes:  256
# Length:  40; Size in bytes:  256
# Length:  41; Size in bytes:  256
# Length:  42; Size in bytes:  256
# Length:  43; Size in bytes:  256
# Length:  44; Size in bytes:  256
# Length:  45; Size in bytes:  256
# Length:  46; Size in bytes:  256
# Length:  47; Size in bytes:  256
# Length:  48; Size in bytes:  256
# Length:  49; Size in bytes:  256
